# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the dataset
iris = load_iris()
X = iris.data  # 4 features
y = iris.target  # class labels

# %%
#Standardize the 
#Data PCA is affected by scale, so we standardize features (mean=0, std=1).
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Apply PCA
#Let’s reduce from 4D → 2D (easy to visualize).
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
#Plot the Results
plt.figure(figsize=(8, 6))
for label in np.unique(y):
    plt.scatter(X_pca[y == label, 0], X_pca[y == label, 1], label=iris.target_names[label])

plt.xlabel("PC1 (Principal Component 1)")
plt.ylabel("PC2 (Principal Component 2)")
plt.title("PCA on Iris Dataset")
plt.legend()
plt.grid(True)
plt.show()

# %%
#Inspect Explained Variance
#Let’s see how much information (variance) each component captures.
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("Total variance retained:", np.sum(pca.explained_variance_ratio_))
# Out:
# Explained variance ratio: [0.72962445 0.22850762]
# Total variance retained: 0.9581320720000166
